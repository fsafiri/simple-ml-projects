# %%
import string
import json
import random
import nltk
import datetime
import numpy as np
import tensorflow as tf
from nltk.stem import WordNetLemmatizer
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from difflib import SequenceMatcher
from tensorflow.keras.utils import plot_model


# Download NLTK data (run these once)
nltk.download("punkt")
nltk.download("wordnet")

# Load JSON data
with open(r"C:\Users\fsafi\OneDrive\intents.json", "r", encoding="utf-8") as json_file:
    data = json.load(json_file)
# Initialize data structures
lemmatizer = WordNetLemmatizer()
words = []
classes = []
documents = []
responses = []

# Process data
for intent in data['intents']:
    for pattern in intent['patterns']:
        tokens = nltk.word_tokenize(pattern)
        words.extend(tokens)
        documents.append((tokens, intent['tag']))
        responses.extend(intent['responses'])
    if intent['tag'] not in classes:
        classes.append(intent['tag'])

# Preprocess words and classes
words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]
words = sorted(set(words))
classes = sorted(set(classes))

# Prepare training data
training = []
out_empty = [0] * len(classes)

for doc, tag in documents:
    bag = [1 if word in doc else 0 for word in words]
    output_row = list(out_empty)
    output_row[classes.index(tag)] = 1
    training.append([bag, output_row])

random.shuffle(training)
train_x = np.array([bag for bag, _ in training])
train_y = np.array([output_row for _, output_row in training])

# Define model architecture
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Define learning rate schedule
initial_learning_rate = 0.01
lr_schedule = ExponentialDecay(
    initial_learning_rate, decay_steps=10000, decay_rate=0.9
)

# Compile the model
model.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
    metrics=['accuracy']
)

# Train the model
model.fit(x=train_x, y=train_y, epochs=150, verbose=1)

# preprocessing functions and get_response function

def clean_text(text):
    tokens = nltk.word_tokenize(text)
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    return tokens

def bag_of_words(text, vocab):
    tokens = clean_text(text)
    bow = [1 if word in tokens else 0 for word in vocab]
    return np.array(bow)

def is_response_similar(response, user_input):
    similarity_threshold = 0.7  # Could be adjusted as needed
    similarity = SequenceMatcher(None, response, user_input).ratio()
    return similarity > similarity_threshold

def pred_class(user_input, vocab, labels):
    bow = bag_of_words(user_input, vocab)
    result = model.predict(np.array([bow]))[0]
    
    # Define the threshold
    threshold = 0.5  # Adjust as needed
    
    # Predicted labels based on the threshold
    predicted_labels = [labels[i] for i, value in enumerate(result) if value > threshold]
    
    # Check if any previous response is similar to the current input
    for response_tuple in conversation_history[::-1]:
        response = response_tuple[0]
        if is_response_similar(response, user_input):
            predicted_labels.append(response)
    
    return predicted_labels


def get_response(intents, data):
    for intent in data['intents']:
        if intent['tag'] in intents:
            return random.choice(intent['responses'])
    return "I'm sorry, I didn't understand that."



# interaction loop
print("Press 0 if you'd like to stop chatting with our ChatBot")

conversation_history = []  # List to store conversation history

while True:
    user_input = input("You: ")
    if user_input == "0":
        break
    
    conversation_history.append(("user", user_input))  # Add user input to history
    
    intents = pred_class(user_input, words, classes)
    response = get_response(intents, data)
    
    conversation_history.append(("chatbot", response))  # Add chatbot response to history
    
    print("ChatBot:", response)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\fsafi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\fsafi\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Epoch 1/150
# 3/3 [==============================] - 1s 6ms/step - loss: 1.6322 - accuracy: 0.1818
# Epoch 2/150
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4210 - accuracy: 0.5000
# Epoch 3/150
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2404 - accuracy: 0.6061
# Epoch 4/150
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1179 - accuracy: 0.6515
# Epoch 5/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9282 - accuracy: 0.6818
# Epoch 6/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7151 - accuracy: 0.8030
# Epoch 7/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6147 - accuracy: 0.8939
# Epoch 8/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3598 - accuracy: 0.9848
# Epoch 9/150
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2696 - accuracy: 0.9545
# Epoch 10/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2178 - accuracy: 0.9697
# Epoch 11/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1573 - accuracy: 0.9697
# Epoch 12/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1902 - accuracy: 0.9394
# Epoch 13/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1690 - accuracy: 0.9697
# Epoch 14/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1637 - accuracy: 0.9545
# Epoch 15/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1967 - accuracy: 0.9394
# Epoch 16/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0828 - accuracy: 0.9848
# Epoch 17/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1528 - accuracy: 0.9697
# Epoch 18/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1521 - accuracy: 0.9545
# Epoch 19/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0902 - accuracy: 0.9697
# Epoch 20/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0769 - accuracy: 0.9697
# Epoch 21/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0918 - accuracy: 0.9848
# Epoch 22/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0708 - accuracy: 0.9848
# Epoch 23/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0498 - accuracy: 0.9848
# Epoch 24/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0670 - accuracy: 0.9848
# Epoch 25/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1103 - accuracy: 0.9697
# Epoch 26/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1026 - accuracy: 0.9848
# Epoch 27/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0570 - accuracy: 0.9848
# Epoch 28/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0433 - accuracy: 0.9848
# Epoch 29/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0575 - accuracy: 0.9697
# Epoch 30/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0862 - accuracy: 0.9848
# Epoch 31/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1336 - accuracy: 0.9697
# Epoch 32/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1675 - accuracy: 0.9697
# Epoch 33/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0984 - accuracy: 0.9697
# Epoch 34/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1370 - accuracy: 0.9697
# Epoch 35/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0988 - accuracy: 0.9848
# Epoch 36/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0615 - accuracy: 0.9848
# Epoch 37/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0897 - accuracy: 0.9848
# Epoch 38/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0754 - accuracy: 0.9848
# Epoch 39/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0807 - accuracy: 0.9848
# Epoch 40/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0769 - accuracy: 0.9848
# Epoch 41/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0849 - accuracy: 0.9848
# Epoch 42/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0591 - accuracy: 0.9848
# Epoch 43/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1318 - accuracy: 0.9545
# Epoch 44/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0682 - accuracy: 0.9848
# Epoch 45/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0707 - accuracy: 0.9848
# Epoch 46/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0806 - accuracy: 0.9848
# Epoch 47/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0698 - accuracy: 0.9848
# Epoch 48/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1076 - accuracy: 0.9848
# Epoch 49/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0818 - accuracy: 0.9848
# Epoch 50/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0554 - accuracy: 0.9848
# Epoch 51/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1487 - accuracy: 0.9848
# Epoch 52/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0929 - accuracy: 0.9848
# Epoch 53/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0686 - accuracy: 0.9848
# Epoch 54/150
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1315 - accuracy: 0.9848
# Epoch 55/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0598 - accuracy: 0.9848
# Epoch 56/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0789 - accuracy: 0.9848
# Epoch 57/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1130 - accuracy: 0.9848
# Epoch 58/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0467 - accuracy: 0.9848
# Epoch 59/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0887 - accuracy: 0.9848
# Epoch 60/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0877 - accuracy: 0.9848
# Epoch 61/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0684 - accuracy: 0.9697
# Epoch 62/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0687 - accuracy: 0.9848
# Epoch 63/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0485 - accuracy: 0.9848
# Epoch 64/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0922 - accuracy: 0.9848
# Epoch 65/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0904 - accuracy: 0.9848
# Epoch 66/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0815 - accuracy: 0.9848
# Epoch 67/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0710 - accuracy: 0.9848
# Epoch 68/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0650 - accuracy: 0.9848
# Epoch 69/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0539 - accuracy: 0.9848
# Epoch 70/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0652 - accuracy: 0.9848
# Epoch 71/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0745 - accuracy: 0.9848
# Epoch 72/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0527 - accuracy: 0.9848
# Epoch 73/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1029 - accuracy: 0.9848
# Epoch 74/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0578 - accuracy: 0.9848
# Epoch 75/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0668 - accuracy: 0.9848
# Epoch 76/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0796 - accuracy: 0.9848
# Epoch 77/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0775 - accuracy: 0.9848
# Epoch 78/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1035 - accuracy: 0.9545
# Epoch 79/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0682 - accuracy: 0.9848
# Epoch 80/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0946 - accuracy: 0.9848
# Epoch 81/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1100 - accuracy: 0.9697
# Epoch 82/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1042 - accuracy: 0.9848
# Epoch 83/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0691 - accuracy: 0.9848
# Epoch 84/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0536 - accuracy: 0.9848
# Epoch 85/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0685 - accuracy: 0.9848
# Epoch 86/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0875 - accuracy: 0.9848
# Epoch 87/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0744 - accuracy: 0.9848
# Epoch 88/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0688 - accuracy: 0.9848
# Epoch 89/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0828 - accuracy: 0.9848
# Epoch 90/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0499 - accuracy: 0.9848
# Epoch 91/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0708 - accuracy: 0.9848
# Epoch 92/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0597 - accuracy: 0.9848
# Epoch 93/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0685 - accuracy: 0.9848
# Epoch 94/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0710 - accuracy: 0.9848
# Epoch 95/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0417 - accuracy: 0.9848
# Epoch 96/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0799 - accuracy: 0.9848
# Epoch 97/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0686 - accuracy: 0.9848
# Epoch 98/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0800 - accuracy: 0.9848
# Epoch 99/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0891 - accuracy: 0.9848
# Epoch 100/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1013 - accuracy: 0.9848
# Epoch 101/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0970 - accuracy: 0.9697
# Epoch 102/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0556 - accuracy: 0.9848
# Epoch 103/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0822 - accuracy: 0.9697
# Epoch 104/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1079 - accuracy: 0.9848
# Epoch 105/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0771 - accuracy: 0.9848
# Epoch 106/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0459 - accuracy: 0.9848
# Epoch 107/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0821 - accuracy: 0.9848
# Epoch 108/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0442 - accuracy: 0.9848
# Epoch 109/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0969 - accuracy: 0.9848
# Epoch 110/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0981 - accuracy: 0.9848
# Epoch 111/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0914 - accuracy: 0.9848
# Epoch 112/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0902 - accuracy: 0.9848
# Epoch 113/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0624 - accuracy: 0.9848
# Epoch 114/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0787 - accuracy: 0.9848
# Epoch 115/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2270 - accuracy: 0.9697
# Epoch 116/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0489 - accuracy: 0.9848
# Epoch 117/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0627 - accuracy: 0.9848
# Epoch 118/150
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0843 - accuracy: 0.9848
# Epoch 119/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0983 - accuracy: 0.9848
# Epoch 120/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1180 - accuracy: 0.9848
# Epoch 121/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1553 - accuracy: 0.9697
# Epoch 122/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1283 - accuracy: 0.9545
# Epoch 123/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0630 - accuracy: 0.9848
# Epoch 124/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0969 - accuracy: 0.9848
# Epoch 125/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0786 - accuracy: 0.9848
# Epoch 126/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0537 - accuracy: 0.9848
# Epoch 127/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1019 - accuracy: 0.9848
# Epoch 128/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1213 - accuracy: 0.9848
# Epoch 129/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0840 - accuracy: 0.9848
# Epoch 130/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1655 - accuracy: 0.9697
# Epoch 131/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1263 - accuracy: 0.9697
# Epoch 132/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1159 - accuracy: 0.9545
# Epoch 133/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0571 - accuracy: 0.9848
# Epoch 134/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0445 - accuracy: 0.9848
# Epoch 135/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1051 - accuracy: 0.9848
# Epoch 136/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1142 - accuracy: 0.9848
# Epoch 137/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0961 - accuracy: 0.9848
# Epoch 138/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0779 - accuracy: 0.9848
# Epoch 139/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0552 - accuracy: 0.9848
# Epoch 140/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0880 - accuracy: 0.9848
# Epoch 141/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0811 - accuracy: 0.9848
# Epoch 142/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0837 - accuracy: 0.9848
# Epoch 143/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0729 - accuracy: 0.9848
# Epoch 144/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0393 - accuracy: 0.9848
# Epoch 145/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0915 - accuracy: 0.9848
# Epoch 146/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0584 - accuracy: 0.9848
# Epoch 147/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0349 - accuracy: 0.9848
# Epoch 148/150
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0705 - accuracy: 0.9848
# Epoch 149/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0558 - accuracy: 0.9848
# Epoch 150/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0374 - accuracy: 0.9848
# Press 0 if you'd like to stop chatting with our ChatBot
# You:  hello
# 1/1 [==============================] - 0s 115ms/step
# ChatBot: Yo !
# You:  i have wifi problem
# 1/1 [==============================] - 0s 22ms/step
# ChatBot: Il semble y avoir un souci avec le wifi. Contacte le service IT pour obtenir de l'aide technique.
# You:  reset
# 1/1 [==============================] - 0s 21ms/step
# ChatBot: Salut à toi !
# You:  reinitialization
# 1/1 [==============================] - 0s 29ms/step
# ChatBot: Salut à tous ! Si vous avez des demandes, je suis là pour vous aider.
# You:  reset
# 1/1 [==============================] - 0s 19ms/step
# ChatBot: Salut à toi !
# You:  0
